# %%
# %load_ext autoreload

# %autoreload 2
import sys
import corner
import numpy as np
import matplotlib.pyplot as plt
import scipy
def binning(corner): return [[corner[i],corner[i+1]] for i in range(len(corner)-1)]
sys.path.append('/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/modules/')
import covariance as covar
import utils
import pandas as pd
import abundance as cl_count
import forecast
import emcee
from lnlikelihood import lnLikelihood
import pyccl as ccl
import edit, sys
import h5py, glob
Omega_c_true = 0.30711 - 0.048254
Omega_b_true = 0.048254
sigma8_true = .8288
Omegam_true = 0.30711
True_value = [Omega_c_true + Omega_b_true, sigma8_true]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def load_pickle(filename, **kwargs):
    with open(filename, 'rb') as fin:
        return pickle.load(fin, **kwargs)

# %%
sys.path.append('/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC')
import analysis

# %%
Om, y = np.load('Om_SSC_contribution_SSC_contribution_binned_full_1_14.70_15.60.pkl', allow_pickle=True)
ssc_contOmfull = [y[i][2] for i in range(len(Om))]
gauss_Omfull = [y[i][0] for i in range(len(Om))]
sn_Omfull = gauss_Omfull[y[i][0] for i in range(len(Om))]

# %%
Om, y = np.load('Om_SSC_contribution_SSC_contribution_binned_approx_1_14.70_15.60.pkl', allow_pickle=True)
ssc_contOmapprox = [y[i][2] for i in range(len(Om))]

# %%
plt.figure(figsize = (4,4))
ax = plt.axes()
ax.set_facecolor("whitesmoke")
dOm = Om[1]-Om[0]


yssn = [ ssn_contOmfull, ]# sn_contOmbinned[0]]
yssc = [ssc_contOmfull,]# ssc_contOmbinned[0]]
x = [ Om]

for i, y_ in enumerate(yssn):
    
    y_post = np.exp(y_ - np.max(y_))
    y_ = y_post/np.trapz(y_post, x[i])
    xmean = np.trapz(y_*x[i],x[i])
    sigma2SN = np.trapz(y_*(x[i] - xmean)**2,x[i])
    print(sigma2SN**.5)
    plt.plot(x[i], .05*y_, ls='-' ,c='k',lw=1)
    #
    #y_post = y_post * np.exp(yssc[i] - np.max(yssc[i]))
    #y_ = y_post/np.trapz(y_post, x[i])
    #xmean = np.trapz(y_*x[i],x[i])
    #sigma2SSC = np.trapz(y_*(x[i] - xmean)**2,x[i])
    #print(sigma2SSC**.5)
    #
    #plt.fill_between(x[i], .05*y_, 0*( .03*y_), alpha=.4)
    #break
#plt.legend(frameon=True, fontsize=11, framealpha=1, facecolor='white', loc= 'upper right')
#plt.vlines(0.30711, 0, 10**7)
#plt.savefig('ssc2.pdf', bbox_inches='tight', dpi=300)
# Out:
# 0.0037520236868433415

# %%
Om, y = np.load('Om_SSC_contribution_SSC_contribution_binned_approx_1_14.70_15.60.pkl', allow_pickle=True)
ssc_contOmapprox = [y[i][2] for i in range(len(Om))]

# %%
plt.figure(figsize = (5,4))
ax = plt.axes()
ax.set_facecolor("whitesmoke")
dOm = Om[1]-Om[0]

plt.plot(Om,ssc_contOmapprox-ssc_contOmapprox[0], 'C0', lw=1, label = 'binned: 10x10')
#ax[1].plot(s8[mask],np.exp(np.array(ssc_conts8binned_0)[mask]), '-c', lw=1)

#plt.plot(Om,ssc_contOmfull-ssc_contOmfull[0], 'C1', lw=1, label = 'binned: 10x10')
#ax[1].plot(s8[mask],np.exp(np.array(ssc_conts8binned_1)[mask]), '-b', lw=1)

plt.legend(frameon=True, fontsize=11, framealpha=.6, facecolor='white', loc= 'upper right')
plt.xlabel(r'$\Omega_m$', fontsize=20)
#ax[1].set_xlabel(r'$\sigma_8$', fontsize=20)
plt.ylabel(r'$\ln(1 + f_{\rm SSC})$', fontsize=20)
#ax[0].set_yscale('log')
#plt.yscale('log')
#plt.ylim(0, 10000)
#plt.ylim(-10, 1)
#plt.xlim(0.2, 0.4)
#plt.vlines(0.30711, 0, 10**7)
# Out:
# Text(0, 0.5, '$\\ln(1 + f_{\\rm SSC})$')
