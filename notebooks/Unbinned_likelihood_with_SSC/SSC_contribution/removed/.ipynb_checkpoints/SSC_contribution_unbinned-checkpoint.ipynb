# %%
# %load_ext autoreload

# %autoreload 2
import sys
import corner
import numpy as np
import matplotlib.pyplot as plt
import scipy
def binning(corner): return [[corner[i],corner[i+1]] for i in range(len(corner)-1)]
import unbinned_likelihood
sys.path.append('/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/modules/')
import covariance as covar
import utils
import pandas as pd
import abundance as cl_count
import forecast
import emcee
import unbinned_model as ub
from lnlikelihood import lnLikelihood
import pyccl as ccl
import edit
import h5py, glob
Omega_c_true = 0.30711 - 0.048254
Omega_b_true = 0.048254
sigma8_true = .8288
Omegam_true = 0.30711
True_value = [Omega_c_true + Omega_b_true, sigma8_true]

# %%
Om, res_large = np.load('large_sample.npy',allow_pickle=True)
Om, res_middle = np.load('middle_sample.npy',allow_pickle=True)
Om, res_small = np.load('small_sample.npy',allow_pickle=True)

# %%
plt.figure(figsize=(5,5))
#plt.style.use('white_background')
y1 = np.exp([np.array(res_large)[i][1] for i in range(len(res_large))])
plt.plot(Om, y1/max(y1), 'r', label = 'large sample')
y2 = np.exp([np.array(res_middle)[i][1] for i in range(len(res_small))])
plt.plot(Om, y2/max(y2), '--b', label = 'average sample')
y2 = np.exp([np.array(res_small)[i][1] for i in range(len(res_small))])
plt.plot(Om, y2/max(y2), 'b', label = 'small sample')
plt.legend(fontsize=15, frameon=False)
plt.xlabel(r'$\Omega_m$', fontsize=20)
plt.vlines(0.30711, 0, 1, color='k', ls='--')

y1 = [np.array(res_small)[i][0] for i in range(len(res_small))]
y1 = y1-max(y1)
y1 = np.exp(y1)
plt.xlim(.2, .5)
plt.ylim(0, 1)
plt.ylabel(r'$P_{\rm SSC}/P_{\rm noSSC}$', fontsize=20)
plt.tick_params(axis='both', which = 'major', labelsize= 13)
plt.savefig('unbinnedSSC_c.png', bbox_inches='tight', dpi=300)
#plt.plot(Om, y1/max(y1), label = 'large')
#plt.yscale('log')

# %%
x = np.linspace(-1, 1, 1000)

# %%
plt.plot(x, x**2)
plt.plot(x, 2*x**2, '*')
