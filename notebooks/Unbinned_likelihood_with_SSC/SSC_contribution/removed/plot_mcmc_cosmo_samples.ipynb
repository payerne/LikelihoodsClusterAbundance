# %%
# %load_ext autoreload

# %autoreload 2
import numpy as np
import corner, sys
import getdist
from getdist import plots, MCSamples
# %matplotlib inline
import matplotlib.pyplot as plt
sys.path.append('../../modules/')
import numpy as np
#plt.switch_backend("Qt5Agg")

# %%
def load_pickle(filename, **kwargs):
    with open(filename, 'rb') as fin:
        return pickle.load(fin, **kwargs)

# %%
d1 = '/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/SSC_contribution/SSC_mcmc/'
d2 = '/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/SSC_contribution/SSC_mcmc_/'

# %%
names = ['1', '2',]
labels = [r'\Omega_m', r'\sigma_8']
settings={'mult_bias_correction_order':0,'smooth_scale_2D':5, 'smooth_scale_1D':4, 'boundary_correction_order':0}

# %%
sample = 'pinocchio'
n_cut=3000
t = np.load(d1+f'mcmc_full_unbinned_sample_{sample}.pkl', allow_pickle = True)
pinocchioPoisson = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson')
sample = 'erosita'
t = np.load(d1+f'mcmc_full_unbinned_sample_{sample}.pkl', allow_pickle = True)
erositaPoisson = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson')
sample = 'spt'
t = np.load(d1+f'mcmc_full_unbinned_sample_{sample}.pkl', allow_pickle = True)
sptPoisson = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson')
sample = 'planck'
t = np.load(d1+f'mcmc_full_unbinned_sample_{sample}.pkl', allow_pickle = True)
planckPoisson = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson')
g = plots.get_subplot_plotter(subplot_size=2.)
g.settings.lab_fontsize = 20
g.settings.legend_fontsize = 12
g.triangle_plot([pinocchioPoisson, erositaPoisson, sptPoisson , planckPoisson  ], 
                filled=[ False, False, False,False,], 
                contour_colors = ['m', 'g', 'r', 'k', 'k', 'k' ], 
                contour_ls=['-','-','--', '-', '-'],
                contour_lws=[1,1,1,1,1],shaded=False,
                legend_fontsize = 10,
                markers = {'1':0.30711, '2':0.8288},
                fine_bins = 1,  marker_args = {'linewidth':10}, )
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
sample = 'pinocchio'
n_cut=3000
t = np.load(d1+f'mcmc_full_unbinned_sample_{sample}.pkl', allow_pickle = True)
pinocchioPoisson = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson')
t = np.load(d1+f'mcmc_hybrid_garrell_unbinned_SSC_sample_{sample}.pkl', allow_pickle = True)
pinocchioSSC = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson+SSC')
g = plots.get_subplot_plotter(subplot_size=2.)
g.settings.lab_fontsize = 20
g.settings.legend_fontsize = 12
g.triangle_plot([pinocchioPoisson, pinocchioSSC ], 
                filled=[True, False, False, False,False,], 
                contour_colors = ['m', 'g', 'r', 'k', 'k', 'k' ], 
                contour_ls=['--','-','-', '-', '-'],
                contour_lws=[1,1,1,1,1],shaded=False,
                legend_fontsize = 10,
                markers = {'1':0.30711, '2':0.8288},
                fine_bins = 1,  marker_args = {'linewidth':10}, )
# Out:
# Removed no burn in
# Removed no burn in

# %%
sample = 'erosita'
n_cut=3000
t = np.load(d1+f'mcmc_full_unbinned_sample_{sample}.pkl', allow_pickle = True)
erositaPoisson = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson')
t = np.load(d1+f'mcmc_hybrid_garrell_unbinned_SSC_sample_{sample}.pkl', allow_pickle = True)
erositaSSC = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson+SSC')
g = plots.get_subplot_plotter(subplot_size=2.)
g.settings.lab_fontsize = 20
g.settings.legend_fontsize = 12
range_ = {'1':[2.5,4], '2':[-2,2], '3':[1,4], '4':[0.1,1.2],'5':[-1.5,1.5], '6':[-0.5,0.5], }
g.triangle_plot([erositaPoisson, erositaSSC ], 
                filled=[True, False, False, False,False,], 
                contour_colors = ['m', 'g', 'r', 'k', 'k', 'k' ], 
                contour_ls=['--','-','-', '-', '-'],
                contour_lws=[1,1,1,1,1],shaded=False,
                legend_fontsize = 10,
                markers = {'1':0.30711, '2':0.8288},
                fine_bins = 1,  marker_args = {'linewidth':10}, )
# Out:
# Removed no burn in
# Removed no burn in

# %%
sample = 'spt'
t = np.load(d1+f'mcmc_full_unbinned_sample_{sample}.pkl', allow_pickle = True)
sptPoisson = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson')
t = np.load(d1+f'mcmc_hybrid_garrell_unbinned_SSC_sample_{sample}.pkl', allow_pickle = True)
sptSSC = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson+SSC')
g = plots.get_subplot_plotter(subplot_size=2.)
g.settings.lab_fontsize = 20
g.settings.legend_fontsize = 12
range_ = {'1':[2.5,4], '2':[-2,2], '3':[1,4], '4':[0.1,1.2],'5':[-1.5,1.5], '6':[-0.5,0.5], }
g.triangle_plot([sptPoisson, sptSSC, ], 
                filled=[True, False, False, False,False,], 
                contour_colors = ['m', 'g', 'r', 'k', 'k', 'k' ], 
                contour_ls=['--','-','-', '-', '-'],
                contour_lws=[1,1,1,1,1],shaded=False,
                legend_fontsize = 10,
                markers = {'1':0.30711, '2':0.8288},
                fine_bins = 1,  marker_args = {'linewidth':10}, )
#plt.savefig(f'../fig/mcmc_scaling_relation_impact_CM_relation.png', dpi = 300)
# Out:
# Removed no burn in
# Removed no burn in

# %%
sample = 'planck'
t = np.load(d1+f'mcmc_full_unbinned_sample_{sample}.pkl', allow_pickle = True)
planckPoisson = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson')
t = np.load(d1+f'mcmc_hybrid_garrell_unbinned_SSC_sample_{sample}.pkl', allow_pickle = True)
planckSSC = MCSamples(samples=t[n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'{sample}-Poisson+SSC')
g = plots.get_subplot_plotter(subplot_size=2.)
g.settings.lab_fontsize = 20
g.settings.legend_fontsize = 12
g.triangle_plot([planckPoisson, planckSSC, ], 
                filled=[True, False, False, False,False,], 
                contour_colors = ['m', 'g', 'r', 'k', 'k', 'k' ], 
                contour_ls=['--','-','-', '-', '-'],
                contour_lws=[1,1,1,1,1],shaded=False,
                legend_fontsize = 10,
                markers = {'1':0.30711, '2':0.8288},
                fine_bins = 1,  marker_args = {'linewidth':10}, )
#plt.savefig(f'../fig/mcmc_scaling_relation_impact_CM_relation.png', dpi = 300)
# Out:
# Removed no burn in
# Removed no burn in
