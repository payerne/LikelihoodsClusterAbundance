# %%
# %load_ext autoreload

# %autoreload 2
import sys
import corner
import numpy as np
import matplotlib.pyplot as plt
import scipy
def binning(corner): return [[corner[i],corner[i+1]] for i in range(len(corner)-1)]
sys.path.append('/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/modules/')
import covariance as covar
import pandas as pd
import abundance as cl_count
import forecast
import emcee
from lnlikelihood import lnLikelihood
import pyccl as ccl
import edit, sys
import h5py, glob
sys.path.append('/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/mcmc_modules/')
import plot_function as plotssc
Omega_c_true = 0.30711 - 0.048254
Omega_b_true = 0.048254
sigma8_true = .8288
Omegam_true = 0.30711
True_value = [Omega_c_true + Omega_b_true, sigma8_true]
import matplotlib as mpl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def load_pickle(filename, **kwargs):
    with open(filename, 'rb') as fin:
        return pickle.load(fin, **kwargs)

# %%
 d = '/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/SSC_contribution/SSC/'

# %%
color = ['C0', 'C1', 'C2']
ls = ['-', '-', '-']

# %%
cat = 120

# %%
name = ['S1 - HLC/Poisson', 'S2 - HLC/Poisson', 'S3 - HLC/Poisson']

# %%
#file = [
#        d+f'full_unbinned_SSC_cat={cat}_sample_S1.pkl',
#        d+f'full_unbinned_SSC_cat={cat}_sample_S2.pkl',
#        d+f'full_unbinned_SSC_cat={cat}_sample_S3.pkl',
#        ]
#plotssc.splot(file = file, name = name, color = color, ls = ls, name_save = 'full')

# %%
#file = [
#        d+f'hybrid_unbinned_SSC_cat={cat}_sample_S1.pkl',
#        d+f'hybrid_unbinned_SSC_cat={cat}_sample_S2.pkl',
#        d+f'hybrid_unbinned_SSC_cat={cat}_sample_S3.pkl',
#        ]
#plotssc.splot(file = file,  name = name, color = color, ls = ls, name_save = 'hybrid')

# %%
#file = [
#        d+f'hybrid_garrell_unbinned_SSC_cat={cat}_sample_S2.pkl',
#        d+f'Gaussian_SSC_binned_cat={cat}_sample_S2.pkl',
#    
#        ]
#plotssc.splot(file = file,  name = name, color = color, ls = ls, name_save = 'binned_vs_unbinned')

# %%
file = [
        d+f'hybrid_garrell_unbinned_SSC_cat={cat}_sample_S1.pkl',
        d+f'hybrid_garrell_unbinned_SSC_cat={cat}_sample_S2.pkl',
        d+f'hybrid_garrell_unbinned_SSC_cat={cat}_sample_S3.pkl',
        ]
plotssc.splot(file = file,  name = name, color = color, ls = ls, name_save = 'hybrid_garrell')
plt.savefig('tests', bbox_inches='tight', dpi=300)
# Out:
# 0.30429 0.00677
# 0.30417 0.00749
# ratio = 1.1063837170757116
# 0.30292 0.00497
# 0.30272 0.00594
# ratio = 1.193826930662451
# 0.30340 0.00423
# 0.30307 0.00536
# ratio = 1.2680806332597705

# %%
color = ['C0', 'k', 'C0', 'k','C0', 'k']
ls = ['-','--','-','--','-','--']
name= [1,1,1,1,1,1]
file = [
        d+f'full_unbinned_cat={cat}_sample_S1.pkl',
          d+f'hybrid_garrell_unbinned_SSC_cat={cat}_sample_S1.pkl',
    
        d+f'full_unbinned_cat={cat}_sample_S2.pkl',
    d+f'hybrid_garrell_unbinned_SSC_cat={cat}_sample_S2.pkl',
    
        d+f'full_unbinned_cat={cat}_sample_S3.pkl',
    d+f'hybrid_garrell_unbinned_SSC_cat={cat}_sample_S3.pkl',
        ]
plotssc.splot_standard(file = file,  name = name, color = color, ls = ls, name_save = 'hybrid_garrell')
# Out:
# 0.30430 0.00677
# 0.30429 0.00677
# 0.30294 0.00497
# 0.30292 0.00497
# 0.30343 0.00423
# 0.30340 0.00423
# 0
