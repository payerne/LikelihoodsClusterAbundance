# %%
# %load_ext autoreload

# %autoreload 2
import sys
import corner
import numpy as np
import matplotlib.pyplot as plt
import scipy
import astropy.units as u
def binning(corner): return [[corner[i],corner[i+1]] for i in range(len(corner)-1)]
sys.path.append('/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/modules/')
import covariance as covar
import utils
import pandas as pd
import abundance as cl_count
import forecast
import emcee
sys.path.append('/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/mcmc_modules')
#import unbinned_model_hybrid as ub
#from lnlikelihood import lnLikelihood
import pyccl as ccl
import edit
import h5py, glob
from astropy.coordinates import SkyCoord
from astropy.table import Table
Omega_c_true = 0.30711 - 0.048254
Omega_b_true = 0.048254
sigma8_true = .8288
Omegam_true = 0.30711
True_value = [Omega_c_true + Omega_b_true, sigma8_true]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
redshift_intervals = [[0.2, 0.25],[0.25, 0.3],[0.3, 0.5], ]

# %%
where_cat = '/sps/lsst/users/cpayerne/1000xsimulations/1000_simulations/afumagalli/catalogs/plc_14/*'
cat = glob.glob(where_cat)
cat_test = pd.read_csv(cat[35] ,sep=' ',skiprows=12, names=['M','z','dec','ra'])
ra, dec, redshift, Mvir = cat_test['ra'], cat_test['dec'], cat_test['z'], cat_test['M']/0.6777
mask = (redshift > .2)&(redshift < .5)
mask = mask &(np.log10(Mvir) > 14.8)&(np.log10(Mvir) < 15.6)
redshift_cut = redshift[mask]
Mvir_cut = Mvir[mask]
z_sample = redshift_cut
logm_sample = np.log10(Mvir_cut)

# %%
mask_random = np.arange(100)
plt.figure(figsize=(5,4),)
redshift_intervals = [[0.2, 0.3],[0.3, 0.4],[0.4, 0.5], ]
plt.scatter(redshift_cut, np.log10(Mvir_cut), s=1, color='k', zorder=100000, marker='*')
for i in range(3):
    print(1)
    mask = (redshift_cut[mask_random] > redshift_intervals[i][0])*(redshift_cut[mask_random] < redshift_intervals[i][1])
    for logm, z in zip(Mvir_cut[mask_random][mask], redshift_cut[mask_random][mask]):
        plt.hlines(np.log10(logm), redshift_intervals[i][0],redshift_intervals[i][1], lw=.3)
plt.xlabel('redshift', fontsize=10)
plt.ylabel(r'$\log_{10}M$', fontsize=10)
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 7
#       5 for i in range(3):
#       6     print(1)
# ----> 7     mask = (redshift_cut[mask_random] > redshift_intervals[i][0])*(redshift_cut[mask_random] < redshift_intervals[i][1])
#       8     for logm, z in zip(Mvir_cut[mask_random][mask], redshift_cut[mask_random][mask]):
#       9         plt.hlines(np.log10(logm), redshift_intervals[i][0],redshift_intervals[i][1], lw=.3)
#
# File ~/.conda/envs/myenv/lib/python3.10/site-packages/pandas/core/series.py:1033, in Series.__getitem__(self, key)
#    1030     key = np.asarray(key, dtype=bool)
#    1031     return self._get_values(key)
# -> 1033 return self._get_with(key)
#
# File ~/.conda/envs/myenv/lib/python3.10/site-packages/pandas/core/series.py:1068, in Series._get_with(self, key)
#    1064 if key_type == "integer":
# ...
