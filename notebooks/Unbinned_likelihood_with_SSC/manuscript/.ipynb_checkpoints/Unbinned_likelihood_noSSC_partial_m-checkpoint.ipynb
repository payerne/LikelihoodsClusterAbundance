# %%
# %load_ext autoreload

# %autoreload 2
import sys
import corner
import numpy as np
import matplotlib.pyplot as plt
import scipy
def binning(corner): return [[corner[i],corner[i+1]] for i in range(len(corner)-1)]
sys.path.append('/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/modules/')
import covariance as covar
import utils
import pandas as pd
import abundance as cl_count
import forecast
import emcee
from lnlikelihood import lnLikelihood
import pyccl as ccl
import edit
import h5py, glob
Omega_c_true = 0.30711 - 0.048254
Omega_b_true = 0.048254
sigma8_true = .8288
Omegam_true = 0.30711
True_value = [Omega_c_true + Omega_b_true, sigma8_true]

#sys.path.append('/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/')
import analysis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
import getdist
from getdist import plots, MCSamples
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
analysis.analysis
# Out:
# {'1': {'name': 'mass_bin_1',
#   'redshift_bins': [[0.2, 1]],
#   'logm_bins': [[14.2, 14.3]],
#   'where_to_save': '/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/manuscript/'},
#  '2': {'name': 'mass_bin_2',
#   'redshift_bins': [[0.2, 1]],
#   'logm_bins': [[14.2, 14.4]],
#   'where_to_save': '/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/manuscript/'},
#  '3': {'name': 'mass_bin_3',
#   'redshift_bins': [[0.2, 1]],
#   'logm_bins': [[14.2, 14.5]],
#   'where_to_save': '/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/manuscript/'},
#  '4': {'name': 'mass_bin_4',
#   'redshift_bins': [[0.2, 1]],
#   'logm_bins': [[14.2, 14.6]],
#   'where_to_save': '/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/manuscript/'},
#  '5': {'name': 'mass_bin_5',
#   'redshift_bins': [[0.2, 1]],
# ...

# %%
err_noSSC = []
fit_noSSC = []
samples_noSSC = []
err_SSC = []
samples_SSC = []
names = ['1', '2','3']
labels =  [r'\Omega_m', r'\sigma_8','n_s']
settings={'mult_bias_correction_order':0,'smooth_scale_2D':6, 'smooth_scale_1D':6, 'boundary_correction_order':0}
z = []
for i in range(9):
    i = i+1
    #try:
    z1 = analysis.analysis[str(i)]['logm_bins'][0][0]
    z2 = analysis.analysis[str(i)]['logm_bins'][0][1]
    z.append(np.mean([z1, z2]))
    samplei = np.load(f'/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/manuscript/noSSC_mass_bin_{i}.npy')
    err_noSSC.append(np.std(samplei[8000:],axis=0))

    samples_noSSC.append(MCSamples(samples=samplei[8000:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label=f'${z1}< z <{z2}$'))
    samplei = np.load(f'/pbs/throng/lsst/users/cpayerne/LikelihoodsClusterAbundance/notebooks/Unbinned_likelihood_with_SSC/manuscript/SSC_mass_bin_{i}.npy')
    err_SSC.append(np.std(samplei[8000:], axis=0))
    samples_SSC.append(MCSamples(samples=samplei[5000:],names = names, 
                    labels = labels, 
                     settings=settings,)) 
                         #label=f'${analysis.redshift_bins[i][0]}< z <{analysis.redshift_bins[i][1]}$'))
    #except: a=1
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
import matplotlib.pylab as pl
colors = plt.cm.get_cmap('cividis', len(samples_noSSC))
c = [colors(i) for i in range(len(samples_noSSC))]

# %%
range_ = {'1':[.25, .39], '2':[.8, .9], '3':[0.9, 1]}

# %%
g = plots.get_subplot_plotter(subplot_size=4)
#plt.style.use('dark_background')
g.triangle_plot(samples_noSSC[0:4] + samples_SSC[0:4],
                upper_roots = [samples_noSSC[4:9] + samples_SSC[4:9]],
                upper_kwargs = {'contour_colors':['b', 'r', 'b', 'r',],'contour_ls':['--', '--', '-', '-'], 'contour_lws':[1.5,1.5,1, 1] }, 
                filled=[False, False, True, True,] ,
              
                param_limits = range_,
                contour_levels=3,
                       fine_bins = 1,  marker_args = {'linewidth':2}, markers={'1':0.30711, '2':.8288,'3':0.96})
#g.triangle_plot(samples_SSC, filled=False, contour_colors = c + ['g'], contour_ls='--',
#                contour_lws=1,
#                       fine_bins = 1,  marker_args = {'linewidth':2}, markers={'1':0.30711, '2':.8288})
#plt.savefig('unbinned_noSSC.png', dpi = 300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-07605eaa2040> in <module>
#       8                 param_limits = range_,
#       9                 contour_levels=3,
# ---> 10                        fine_bins = 1,  marker_args = {'linewidth':2}, markers={'1':0.30711, '2':.8288,'3':0.96})
#      11 #g.triangle_plot(samples_SSC, filled=False, contour_colors = c + ['g'], contour_ls='--',
#      12 #                contour_lws=1,
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/GetDist-1.4-py3.7.egg/getdist/plots.py in triangle_plot(self, roots, params, legend_labels, plot_3d_with_param, filled, shaded, contour_args, contour_colors, contour_ls, contour_lws, line_args, label_order, legend_ncol, legend_loc, title_limit, upper_roots, upper_kwargs, upper_label_right, diag1d_kwargs, markers, marker_args, param_limits, **kwargs)
# ...

# %%
import pandas as pd

# %%
where_cat = '/sps/lsst/users/cpayerne/1000xsimulations/1000_simulations/afumagalli/catalogs/plc_14/*'
cat = glob.glob(where_cat)
for i ,cs in enumerate(cat):
    cat_test = pd.read_csv(cs ,sep=' ',skiprows=12, names=['M','z','dec','ra'])
    ra, dec, redshift, Mvir = cat_test['ra'], cat_test['dec'], cat_test['z'], cat_test['M']/0.6777
    if i == 3: break

# %%
n = []
for i in range(9):
    i = i+1
    logmmin = analysis.analysis[str(i)]['logm_bins'][0][0]
    logmmax = analysis.analysis[str(i)]['logm_bins'][0][1]
    zmin = analysis.analysis[str(i)]['redshift_bins'][0][0]
    zmax = analysis.analysis[str(i)]['redshift_bins'][0][1]
    mask = (redshift > zmin)&(redshift < zmax)
    mask = mask &(np.log10(Mvir) > logmmin)&(np.log10(Mvir) < logmmax)
    redshift_cut = redshift[mask]
    Mvir_cut = Mvir[mask]
    print(len(Mvir_cut))
    n.append(len(Mvir_cut))
# Out:
# 32233
# 52745
# 65722
# 73587
# 78225
# 80856
# 82162
# 82835
# 83345

# %%
plt.plot(n, (np.array(err_noSSC)[:,0]/np.array(err_SSC)[:,0]), )
plt.plot(n,(np.array(err_noSSC)[:,1]/np.array(err_SSC)[:,1]), )
plt.plot(n,(np.array(err_noSSC)[:,2]/np.array(err_SSC)[:,2]), )

#plt.plot(n, np.array(err_noSSC)[:,1]/np.array(err_SSC)[:,1]-1)
#plt.plot(n, np.array(err_noSSC)[:,2]/np.array(err_SSC)[:,2]-1)
#plt.plot(n, 0*np.array(n), '--')
